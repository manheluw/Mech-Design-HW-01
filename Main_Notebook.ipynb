# %%
from interactive_calc_template import create_variable_interface

n_variables = 5

title = "My Parameters"

def my_calculation(variables):
    params = {v['name']: v['value'] for v in variables.values()}
    
    print("="*50)
    for name, val in params.items():
        print(f"  {name} = {val}")
    print("="*50)
    
    # === YOUR CODE HERE ===

interface = create_variable_interface(n_variables, title, my_calculation)
